# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('world_Data.csv')

# %%
data.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 3                   Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 4  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
#
#       1996 [YR1996]     1997 [YR1997]     1998 [YR1998]     1999 [YR1999]  \
# 0                ..                ..                ..                ..
# 1                ..                ..                ..                ..
# 2  57.8255675029869  57.8837729375364  58.0017155285973  57.8270992249487
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5857 entries, 0 to 5856
# Data columns (total 29 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   5854 non-null   object
#  1   Country Code   5852 non-null   object
#  2   Series Name    5852 non-null   object
#  3   Series Code    5852 non-null   object
#  4   1996 [YR1996]  5852 non-null   object
#  5   1997 [YR1997]  5852 non-null   object
#  6   1998 [YR1998]  5852 non-null   object
#  7   1999 [YR1999]  5852 non-null   object
#  8   2000 [YR2000]  5852 non-null   object
#  9   2001 [YR2001]  5852 non-null   object
#  10  2002 [YR2002]  5852 non-null   object
#  11  2003 [YR2003]  5852 non-null   object
#  12  2004 [YR2004]  5852 non-null   object
#  13  2005 [YR2005]  5852 non-null   object
#  14  2006 [YR2006]  5852 non-null   object
#  15  2007 [YR2007]  5852 non-null   object
#  16  2008 [YR2008]  5852 non-null   object
# ...

# %%
data2 = data.melt(
    id_vars= ["Country Name", "Country Code", "Series Name", "Series Code"],
    var_name= "Year_label",
    value_name= "Value"
)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146425 entries, 0 to 146424
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Country Name  146350 non-null  object
#  1   Country Code  146300 non-null  object
#  2   Series Name   146300 non-null  object
#  3   Series Code   146300 non-null  object
#  4   Year_label    146425 non-null  object
#  5   Value         146300 non-null  object
# dtypes: object(6)
# memory usage: 6.7+ MB

# %%
data2.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)     EG.ELC.ACCS.ZS
# 2                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 3                   Agricultural machinery, tractors     AG.AGR.TRAC.NO
# 4  Agricultural raw materials exports (% of merch...  TX.VAL.AGRI.ZS.UN
#
#       Year_label             Value
# 0  1996 [YR1996]                ..
# 1  1996 [YR1996]                ..
# 2  1996 [YR1996]  57.8255675029869
# 3  1996 [YR1996]               110
# 4  1996 [YR1996]                ..

# %%
data2['Year'] = data2['Year_label'].str[:4]

# %%
data2.head(2)
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
#
#                                          Series Name     Series Code  \
# 0  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)  EG.ELC.ACCS.ZS
#
#       Year_label Value  Year
# 0  1996 [YR1996]    ..  1996
# 1  1996 [YR1996]    ..  1996

# %%
data2['Year'] = data2['Year'].astype(int)

# %%
data2['Value'] = data2['Value'].replace("..", np.nan)

# %%
data2['Value'] = data2['Value'].astype(float)

# %%
data2.head(2)
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
#
#                                          Series Name     Series Code  \
# 0  Access to clean fuels and technologies for coo...  EG.CFT.ACCS.ZS
# 1            Access to electricity (% of population)  EG.ELC.ACCS.ZS
#
#       Year_label  Value  Year
# 0  1996 [YR1996]    NaN  1996
# 1  1996 [YR1996]    NaN  1996

# %%
data2.to_csv('world_Data_unpivoted.csv')
